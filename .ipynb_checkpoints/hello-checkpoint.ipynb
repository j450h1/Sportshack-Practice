# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline 
# pd.__version__

# %%
print("Hello, World!")
# Out:
# Hello, World!

# %%
bl_1997 = pd.read_csv('datasets/1997business_licences.csv')
bl_1998 = pd.read_csv('datasets/1998business_licences.csv')
bl_1999 = pd.read_csv('datasets/1999business_licences.csv')
bl_2000 = pd.read_csv('datasets/2000business_licences.csv')
bl_2001 = pd.read_csv('datasets/2001business_licences.csv')
bl_2002 = pd.read_csv('datasets/2002business_licences.csv')
bl_2003 = pd.read_csv('datasets/2003business_licences.csv')
bl_2004 = pd.read_csv('datasets/2004business_licences.csv')
bl_2005 = pd.read_csv('datasets/2005business_licences.csv')
bl_2006 = pd.read_csv('datasets/2006business_licences.csv')
bl_2007 = pd.read_csv('datasets/2007business_licences.csv')
bl_2008 = pd.read_csv('datasets/2008business_licences.csv')
bl_2009 = pd.read_csv('datasets/2009business_licences.csv')
bl_2010 = pd.read_csv('datasets/2010business_licences.csv')
bl_2011 = pd.read_csv('datasets/2011business_licences.csv')
bl_2012 = pd.read_csv('datasets/2012business_licences.csv')
bl_2013 = pd.read_csv('datasets/2013business_licences.csv')
bl_2014 = pd.read_csv('datasets/2014business_licences.csv')
bl_2015 = pd.read_csv('datasets/business_licences.csv')
bl_all = pd.concat([bl_1997, bl_1998, bl_1999, bl_2000, bl_2001, bl_2002, bl_2003, bl_2004, bl_2005, bl_2006, bl_2007, bl_2008, bl_2009, bl_2010, bl_2011, bl_2012, bl_2013, bl_2014, bl_2015])
bl_all.describe()
# Out:
#        LicenceRSN LicenceNumber  LicenceRevisionNumber  \
# 63796      122606     98-162118                      0
# 63797      122492     98-162005                      0
# 63798      122489     98-162002                      0
# 63799      122844     98-162355                      0
# 63800      122839     98-162350                      0
# 63801      122833     98-162344                      0
# 63802      122759     98-162270                      0
# 63803      123051     98-162562                      0
# 63804      121934     98-161448                      0
# 63805      122117     98-161631                      0
#
#                                            BusinessName  \
# 63796                        Danny Wong & Tun Hai Wong
# 63797                               Li Kai Sum (Li Sum)
# 63798  The Renaissance Commercial Cleaning Company Inc
# 63799   Royal Canadian Legion Collingwood Branch No 48
# 63800             Vancouver Masonic Temple Association
# 63801    The Association Of United Ukrainian Canadians
# 63802                                     (Sheng-Yi Wu)
# 63803                           (Christopher Colangelo)
# 63804                                       (David Eng)
# 63805               Chris Chong Amiee Chan (Chris Chan)
#
#                               BusinessTradeName   Status           IssuedDate  \
# 63796          Long On Landscaping & Gardening    Issued  1998-01-06 00:00:00
# 63797                     Specialty Decoration    Issued  1998-01-05 00:00:00
# 63798                                       NaN   Issued  1998-01-05 00:00:00
# 63799                                       NaN   Issued  1998-02-12 16:18:25
# 63800                                       NaN   Issued  1998-02-25 09:23:52
# 63801                                       NaN   Issued  1998-03-21 00:00:00
# 63802  Dragonlink International Trade (Canada)    Issued  1998-01-06 00:00:00
# 63803                                       NaN  Pending                  NaN
# 63804                            David Eng CGA    Issued  1998-01-02 00:00:00
# 63805                            Atc Solutions    Issued  1998-01-02 00:00:00
#
#                ExpiredDate         BusinessType            BusinessSubType  \
# 63796  1998-12-31 00:00:00   Landscape Gardener                        NaN
# 63797  1998-12-31 00:00:00               Office  Interior Design/Decorator
# 63798  1998-12-31 00:00:00  Janitorial Services                        NaN
# 63799  1998-12-31 00:00:00        Assembly Hall                        NaN
# 63800  1998-12-31 00:00:00        Assembly Hall                        NaN
# 63801  1998-12-31 00:00:00        Assembly Hall                        NaN
# 63802  1998-12-31 00:00:00               Office             Administration
# 63803                  NaN       Auto Detailing                        NaN
# 63804  1998-12-31 00:00:00   Financial Services         Accountant/Auditor
# 63805  1998-12-31 00:00:00               Office                 Consultant
#
#           ...            City Province Country PostalCode  \
# 63796     ...       Vancouver       BC     NaN    V5K 1L6
# 63797     ...       Vancouver       BC     NaN        NaN
# 63798     ...       Vancouver       BC     NaN    V6G 1L1
# 63799     ...       Vancouver       BC     NaN     V5R5K3
# 63800     ...       Vancouver       BC     CAN    V6H 1C9
# 63801     ...       Vancouver       BC     CAN    V6E 1V9
# 63802     ...       Vancouver       BC     CAN    V6E 1T8
# 63803     ...       Vancouver       BC     NaN     V5Z1R7
# 63804     ...       Vancouver       BC     CAN    V5Z 1G2
# 63805     ...       Vancouver       BC     NaN    V5X 3R6
#
#                     LocalArea NumberOfEmployees   Latitude   Longitude  \
# 63796     05-Hastings-Sunrise                 0  49.287016 -123.051095
# 63797     05-Hastings-Sunrise                 0  49.285097 -123.056073
# 63798             01-West End                 0  49.291396 -123.139066
# 63799  16-Renfrew-Collingwood                 0        NaN         NaN
# 63800             08-Fairview                 0        NaN         NaN
# 63801           03-Strathcona                 0  49.280395 -123.087017
# 63802             01-West End                 0        NaN         NaN
# 63803             08-Fairview                 0        NaN         NaN
# 63804             08-Fairview                 0  49.262955 -123.118391
# 63805               19-Sunset                 0  49.212725 -123.097599
#
#       FeePaid  ExtractDate
# 63796      88   2015-10-19
# 63797      88   2015-10-19
# 63798     108   2015-10-19
# 63799      88   2015-10-19
# 63800      88   2015-10-19
# 63801     173   2015-10-19
# 63802      88   2015-10-19
# 63803     NaN   2015-10-19
# 63804      88   2015-10-19
# 63805      88   2015-10-19
#
# [10 rows x 24 columns]
